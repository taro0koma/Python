# %%
import matplotlib.pyplot as plt
from sklearn import datasets  # digitsなどcsvデータをリストとして取り出すためのメソッド

digits=datasets.load_digits()
# digits のラベル（target)と画像(images)は31枚目以降ランダムになる

for n, (label,img) in enumerate(zip(digits.target[80:100],digits.images[80:100])):
    ax=plt.subplot(4,5,n+1)
    plt.imshow(img,cmap=plt.cm.gray_r,interpolation='nearest')
    plt.title('Digit:{0}'.format(label))
    plt.axis('off')  # xy軸にメモリを入れる

plt.subplots_adjust(hspace=0.8,wspace=0.4)
plt.show()

flag_3_8=(digits.target==3)+(digits.target==8)
print(len(flag_3_8[flag_3_8]))
train_size=int(len(flag_3_8[flag_3_8])*3/5)  # [:train_size]と[train:size]で分割できる
print(test)
images=digits.images[flag_3_8]
images=images.reshape(images.shape[0],-1)
labels=digits.target[flag_3_8]

import numpy as np
np.set_printoptions(threshold=np.inf)


from sklearn import tree
classifier=tree.DecisionTreeClassifier()
classifier.fit(images[:train_size],labels[:train_size])
classifier.fit(images[:train_size],labels[:train_size])

import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz
export_graphviz(classifier, "tree1.dot",class_names=["3","8"])
 
with open("tree1.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
# Out:
# 357
# 214

# %%
import numpy as np
images=np.empty((0,64),np.float64)
images.shape
# 2次元内に64要素できるサイズを準備したリストを作る
images=digits.images[flag_3_8].reshape(-1,64)
print(digits.images[flag_3_8].shape,"を(-1,64)にリシェイプする→",images.shape)
print("(357,-1)にリシェイプするのと同じ→",digits.images[flag_3_8].reshape(digits.images[flag_3_8].shape[0],-1).shape)
# Out:
# (357, 8, 8) を(-1,64)にリシェイプする→ (357, 64)
# (357,-1)にリシェイプするのと同じ→ (357, 64)

# %%
import numpy as np
images=digits.images[flag_3_8].reshape(-1,64)
images=images[:train_size]
images3=np.empty((0,64),np.float64)
print(images.shape)
y=n=0
for i in range(images.shape[0]):
    if images[i][43]<=1.5:
        y+=1
        images3=np.append(images3,np.array([images[i]]),axis=0)
    else:
        n+=1
print(y,n,i)
# Out:
# (214, 64)
# 111 103 213
# array([[ 0.,  0.,  7., 15., 13.,  1.,  0.,  0.,  0.,  8., 13.,  6., 15.,
#          4.,  0.,  0.,  0.,  2.,  1., 13., 13.,  0.,  0.,  0.,  0.,  0.,
#          2., 15., 11.,  1.,  0.,  0.,  0.,  0.,  0.,  1., 12., 12.,  1.,
#          0.,  0.,  0.,  0.,  0.,  1., 10.,  8.,  0.,  0.,  0.,  8.,  4.,
#          5., 14.,  9.,  0.,  0.,  0.,  7., 13., 13.,  9.,  0.,  0.],
#        [ 0.,  2.,  9., 15., 14.,  9.,  3.,  0.,  0.,  4., 13.,  8.,  9.,
#         16.,  8.,  0.,  0.,  0.,  0.,  6., 14., 15.,  3.,  0.,  0.,  0.,
#          0., 11., 14.,  2.,  0.,  0.,  0.,  0.,  0.,  2., 15., 11.,  0.,
#          0.,  0.,  0.,  0.,  0.,  2., 15.,  4.,  0.,  0.,  1.,  5.,  6.,
#         13., 16.,  6.,  0.,  0.,  2., 12., 12., 13., 11.,  0.,  0.],
#        [ 0.,  0., 10.,  7., 13.,  9.,  0.,  0.,  0.,  0.,  9., 10., 12.,
#         15.,  2.,  0.,  0.,  0.,  4., 11., 10., 11.,  0.,  0.,  0.,  0.,
#          1., 16., 10.,  1.,  0.,  0.,  0.,  0., 12., 13.,  4.,  0.,  0.,
# ...

# %%
images33 = np.empty((0,64),np.float64)
images88 = np.empty((0,64),np.float64)
print(images3.shape)
y=n=0
for i in range(images3.shape[0]):
    if images3[i][34] <= 5.5:
        y += 1
        images33 = np.append(images33, np.array([images3[i]]), axis=0 )
    else:
        n += 1
        images88 = np.append(images88, np.array([images3[i]]), axis=0 )
print(y,n,i)
# Out:
# (111, 64)
# 95 16 110

# %%
 
print(images88.shape)
y=n=0
for i in range(images88.shape[0]):
    if images88[i][46] <= 5.5:
        y += 1
    else:
        n += 1
print(y,n,i)
# Out:
# (16, 64)
# 12 4 15

# %%
images333=np.empty((0,64),np.float64)
images888=np.empty((0,64),np.float64)
y=n=0
for i in range(images88.shape[0]):
    if images88[i][46]<=5.5:
        y+=1
        # images888に行を追加する
        # axis=0とすることで行方向の追加ができる
        # axis=1だと列方向の追加になるので、すでに行が存在していないと困る
        images888=np.append(images888,np.array([images88[i]]),axis=0)
    else:
        n+=1
        images333=np.append(images333,np.array([images88[i]]),axis=0)
print(y,n,1)
# Out:
# 12 4 1

# %%
import matplotlib.pyplot as plt
num=len(images888)
for n,img in enumerate(images888):
    plt.subplot(int(num/5)+1,5,n+1)
    plt.axis('off')
    plt.title('n:{0}'.format(n))
    plt.imshow(img.reshape(8,8),cmap=plt.cm.gray_r,interpolation='nearest')
plt.show()

# %%
 
err_lst = []
images=digits.images[flag_3_8].reshape(-1,64)
expected=labels[train_size:]
predicted=classifier.predict(images[train_size:])
for i, n in enumerate(expected != predicted):
    if n :
        err_lst.append(i)
 
list(expected != predicted)
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
 
images = digits.images[flag_3_8]
test_img = images[train_size:]
 
for n , i in enumerate(err_lst):
    img = test_img[i]
    plt.subplot(3,(len(err_lst)/3)+1,n+1)
    plt.axis('off')
    plt.subplots_adjust(hspace=0.2
                        ,wspace=0.8)
    plt.title('{0} {1}→{2}'.format(i,expected[i], predicted[i]))
    plt.imshow(img, cmap=plt.cm.gray_r, interpolation='nearest')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.model_selsction import train_test_split
from sklearn.tree import DecisionTreeClassifier

moons=make_moons(n_samples=200,noise=0.1,random_state=0)
X=mpp
